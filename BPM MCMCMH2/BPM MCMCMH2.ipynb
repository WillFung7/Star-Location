# %%
import numpy as np
from scipy import fft, optimize
import NAFFlib as naf
import statistics as st
import matplotlib.pyplot as plt
import time
from IPython.display import display, Math
import re
import csv

# %%
import os
os.environ['OMP_NUM_THREADS'] = '6'

# %% [markdown]
# # BPM Data

# %%
#Get data from all BPMs from sdds file
Name_xbpms = []
Name_ybpms = []
Pos_xbpms = np.zeros([1024, 168])
Pos_ybpms = np.zeros([1024, 167])
S_xbpms = np.zeros([1024, 168])
S_ybpms = np.zeros([1024, 167])
with open('data_Wed_Jun_28_20-13-14_2023') as output:
    Lines = output.readlines()
    index_ix = index_jx = 0
    index_iy = index_jy = 0
    init_i = 414
    for i, line in enumerate(Lines[1:]):
        Line = []
        #xBPM Names
        if i >= 67 and i < 95:
            for word in re.split("\s+", line):
                Line.append(word)
            Name_xbpms.append(Line[:-1])
        
        #yBPM Names
        if i >= 241 and i < 269:
            for word in re.split("\s+", line):
                Line.append(word)
            Name_ybpms.append(Line[:-1])
           
        #s and positions for xBPM
        if i > init_i:
            row = re.split("\s+", line)
            S_xbpms[index_ix][index_jx] = float(row[1])
            Pos_xbpms[index_ix][index_jx] = float(row[2])
            index_jx = (i - init_i)%168
            
            if (i - init_i)%168 == 0 and (i - init_i) != 0:
                index_ix += 1
        
        #s and positions for yBPM
        if i > init_i and i < 171423:
            row = re.split("\s+", line)
            S_ybpms[index_iy][index_jy] = float(row[6])
            Pos_ybpms[index_iy][index_jy] = float(row[7])
            index_jy = (i - init_i)%167
            
            if (i - init_i)%167 == 0 and (i - init_i) != 0:
                index_iy += 1
        
Name_xbpms = [item for row in Name_xbpms for item in row]
Name_ybpms = [item for row in Name_ybpms for item in row]

# %%
# Positions
init_turn = 0 # Starting turn
BPMx = Pos_xbpms.T[:, init_turn:] #np.loadtxt('BPMx.csv', delimiter=',')[:, init_turn:]
BPMy = Pos_ybpms.T[:, init_turn:] #np.loadtxt('BPMy.csv', delimiter=',')[:, init_turn:]

N_BPMx, N_turns = np.shape(BPMx) #(168, 1024-init_turn)
N_BPMy, _ = np.shape(BPMy) #(167, 1024-init_turn)

#Tunes
Nu_x_meas, Nu_y_meas = 28.235001748, 29.2290029334
nu_x_meas, nu_y_meas = Nu_x_meas%1, Nu_y_meas%1

x = np.linspace(init_turn, N_turns, N_turns)
Omega = np.linspace(0, N_turns//2, N_turns//2)/N_turns

# %%
# Look at first BPM Signals
BPMx0 = BPMx[0]

BPMx0_mean = np.mean(BPMx0)
BPMx0_std = np.std(BPMx0)
print("Standard deviation of First Horizontal BPM =", BPMx0_std)

x = np.linspace(init_turn, N_turns, N_turns)
plt.plot(x, BPMx0)
plt.axhline(y = BPMx0_mean, color = 'b', linestyle = '-', linewidth = .75, label = r"mean = %f"%BPMx0_mean)
plt.xlabel("Turns")
plt.ylabel("Horizontal Offset [mm]")
plt.title("Horizontal Signal of BPM 1")
plt.legend()
plt.show()

BPMy0 = BPMy[0]

BPMy0_mean = np.mean(BPMy0)
BPMy0_std = np.std(BPMy0)
print("Standard deviation of First Vertical BPM =", BPMy0_std)

x = np.linspace(init_turn, N_turns, N_turns)
plt.plot(x, BPMy0)
plt.axhline(y = BPMy0_mean, color = 'b', linestyle = '-', linewidth = .75, label = r"mean = %f"%BPMy0_mean)
plt.xlabel("Turns")
plt.ylabel("Vertical Offset [mm]")
plt.title("Vertical Signal of BPM 1")
plt.legend()
plt.show()
# Out:
# Standard deviation of First Horizontal BPM = 0.08086005371776343
# Standard deviation of First Vertical BPM = 0.14039846131415454

# %%
# Look at First BPM FFTs
BPMX0 = np.abs(fft.rfft(BPMx0)[1:])
BPMx0_Tune_scipy = Omega[np.argmax(BPMX0)]
print(BPMx0_Tune_scipy)
plt.plot(Omega, BPMX0)
plt.axvline(x = BPMx0_Tune_scipy, color = 'b', linestyle = '-', linewidth = .75, label = r"$\nu_x$ = %f"%BPMx0_Tune_scipy)
plt.title("FFT at Horizontal BPM 1")
plt.xlabel(r"$\omega$")
plt.ylabel(r"F($\omega$)")
plt.show()

BPMY0 = np.abs(fft.rfft(BPMy0)[1:])
BPMy0_Tune_scipy = Omega[np.argmax(BPMY0)]
print(BPMy0_Tune_scipy)
plt.plot(Omega, BPMY0)
plt.axvline(x = BPMy0_Tune_scipy, color = 'b', linestyle = '-', linewidth = .75, label = r"$\nu_y$ = %f"%BPMy0_Tune_scipy)
plt.title("FFT at Vertical BPM 1")
plt.xlabel(r"$\omega$")
plt.ylabel(r"F($\omega$)")
plt.show()
# Out:
# 0.23483365949119372
# 0.22896281800391388

# %%
# Look at all FFTs to figure out Tune of machine
BPMx_Tune_Map = np.zeros(N_BPMx)
for i in range(N_BPMx):
    BPMX = np.abs(fft.rfft(BPMx[i])[1:]) 
    BPMx_Tune_Map[i] = Omega[np.argmax(BPMX)]
    # BPM 113 had a flat line

BPMy_Tune_Map = np.zeros(N_BPMy)
for i in range(N_BPMy):
    BPMY = np.abs(fft.rfft(BPMy[i])[1:])
    BPMy_Tune_Map[i] = Omega[np.argmax(BPMY)]

nu_x, nu_y = st.mode(BPMx_Tune_Map), st.mode(BPMy_Tune_Map)
#Difference from experiment
delta_nu_x, delta_nu_y = abs(nu_x_meas - nu_x), abs(nu_y_meas - nu_y)
print(delta_nu_x, delta_nu_y)

plt.plot(BPMx_Tune_Map, color = 'b', label = r"$\nu_x$")
plt.axhline(y = nu_x, color = 'b', linestyle = '-', linewidth = .75, label = r"$\nu_x$ = %f"%nu_x)
plt.plot(BPMy_Tune_Map, color = 'r', label = r"$\nu_y$")
plt.axhline(y = nu_y, color = 'r', linestyle = '-', linewidth = .75, label = r"$\nu_y$ = %f"%nu_y)
plt.xlabel("BPM number")
plt.ylabel(r"$\nu$")
plt.title("Tune measurements of BPMS")
plt.legend()
plt.show()
# Out:
# 0.00016808850880467574 0.0010185889772997558

# %%
# Collect bad BPMs
def Bad_Bpms(Tune_Map, nu, N_BPM):
    Tune_Offset = np.abs(Tune_Map - np.ones(N_BPM)*nu)
    Bad_BPM = []
    for i, offset in enumerate(Tune_Offset):
        if offset > .01:
            Bad_BPM.append(i)
    return Bad_BPM

# %% [markdown]
# # Monte Carlo-Markov Chain Metropolis Hastings Method to find Amplitude

# %%
#Monte Carlo-Markov Chain Metropolis Hastings Functions by Yue Hao
def model(x0, x0p, xc, tunex, eps_sr, eps_nl, xisige, nvs, phis, Nturn=N_turns):
    alpha = 0
    beta = 1
    turns = np.arange(Nturn)
    phi = 2*np.pi*tunex
    
    cs = np.cos(turns*phi)
    sn = np.sin(turns*phi)
    m11 = cs + alpha*sn
    m12 = beta*sn
    
    alpha = 2*xisige*np.sin(np.pi*nvs*turns + phis)/nvs
    alpha02 = (2*xisige*np.sin(phis)/nvs)**2
    decay = np.exp(-(alpha**2 - alpha02)/2 - (eps_nl*turns)**2 - eps_sr*turns)
    return (m11*(x0 - xc) + m12*x0p)*decay + xc

def log_likelihood(theta, sigma, data):
    
    predicted_data = model(*theta, len(data)) 
    diff = predicted_data-data
    ss = sigma[0]*sigma[0]+sigma[1]*sigma[1]*data*data
    
    return -np.sum(diff*diff/2.0/ss) - np.sum(np.log(np.sqrt(ss)))#*len(diff)


def metropolis_hastings(lf, data, iters, pinitials, p_step,
                        sinitials=[1e-4,1e-4], s_step=[1e-4,1e-4]):
    psamples = np.zeros((iters, len(pinitials)))
    ssamples = np.zeros((iters, 2))
    p = np.array(pinitials)
    s = np.array(sinitials)
    pstep = np.array(p_step)
    sstep = np.array(s_step)
    changed = False
    old_lh = lf(p,s, data)
    i = 0
    while i<iters:
        p_n = p + np.random.normal(size=len(pinitials))*pstep
        s_n = s + np.random.normal(size=len(sinitials))*sstep
        if p_n[4] < 0: # SR_eps  > 0
            continue
        if p_n[5] < 0: # nl_eps  > 0
            continue
        if p_n[6] < 0: # xi*sige > 0
            continue
        if p_n[7] <= 0: # nuz > 0
            continue
        if p_n[8] > np.pi:
            p_n[8] -= 2*np.pi
        if p_n[8] < -np.pi: 
            p_n[8] += 2*np.pi
        if s_n[0] < 0: # error rms size >0
            continue
        if s_n[1] < 0: # error rms size >0
            continue
        if changed:
            #old_lh=lf(p,s, data)
            old_lh = new_lh
            
        new_lh = lf(p_n,s_n, data)#-((p_n[0]-data[0])*(p_n[0]-data[0])/2/s_n/s_n+np.log(s_n))#*len(data)
        if np.log(np.random.rand()+1.0e-10) < new_lh - old_lh:
            p,s = p_n,s_n
            changed = True
        else:
            changed = False
        psamples[i] = p
        ssamples[i] = s
        i += 1
    return psamples, ssamples

# %%
# Initial conditions for Horizontal BPMs
pinitials = [BPMx0[0], 0.0, BPMx0_mean, BPMx0_Tune_scipy, 0.0,  0.0, 0, 1e-2, 0.5]
p_step = [1e-3, 1e-3, 1e-3, 5e-7, 0, 0, 0, 0, 0]
sinitials = [1e-2, 0e-2]
s_step = [2e-4, 0e-3]
initial = 35

pinitials[4] = 0.0018
pinitials[5] = 0.0006
pinitials[6] = 0.00073
pinitials[7] = 1e-2
pinitials[8] = 1
p_step[4] = 1e-5
p_step[5] = 1e-5
p_step[6] = 1e-4
p_step[7] = 1e-4
p_step[8] = 3e-2
N_iter = 150000

# Run MCMCMH Simulation for Horizontal BPMs
begin = time.time()
# parr : iters x 11; sarr = iters x 2
parr, sarr = metropolis_hastings(log_likelihood, BPMx0[initial: N_turns//2 + initial], N_iter, 
                              pinitials, p_step, sinitials, s_step)
end = time.time()
print("Time elapsed for full model:", end - begin)
# Out:
# Time elapsed for full model: 27.735356092453003

# %%
# Look at how variables change with # iterations
nrow = 3
ncol = 3
Theta_names = [r"$x_0$", r"$P_x$", r"$x_c$", r"$\nu_x$", r"$\epsilon_{SR}$", 
              r"$\epsilon_{NL}$", r"$\epsilon_E$", r"$\nu_s$", r"$\phi_s$"]
N_var = len(Theta_names)
N_iter = len(parr)
fig, Ax = plt.subplots(nrow, ncol*2, gridspec_kw = {'width_ratios':[5, 1]*ncol}, figsize=(12, 8))
fig.suptitle('Full Model')
split = N_iter//2
x_iter = np.linspace(0, N_iter//1000, N_iter)
Center = []
Stddev = []

for i in range(nrow):
    for j in range(ncol):
        if i*ncol + j >= N_var:
            break
        target = parr.T[i*ncol + j]
        Ax[i][j*2].set_xlabel("Thousand Iterations")
        Ax[i][j*2].set_ylabel(Theta_names[i*ncol + j])
        Ax[i][j*2].plot(x_iter, target)
        Ax[i][j*2].axvspan(split/1000, N_iter/1000, alpha = 0.1, color = 'c')
        Ax[i][j*2].axvline(split/1000, color = 'c', alpha = 0.1)
        center, stddev = np.average(target[split:]), np.std(target[split:])
        Center.append(center)
        Stddev.append(stddev)
        
        hist_data,_,_ = Ax[i][j*2 + 1].hist(target[split:], orientation='horizontal', density=True, color='c', bins=7)
        Ax[i][j*2 + 1].set_xlim([0, np.max(hist_data)*1.1])
        Ax[i][j*2 + 1].set_ylim([np.min(target), np.max(target)])
        Ax[i][j*2 + 1].get_yaxis().set_visible(False)
        
        
plt.subplots_adjust(wspace=0.0)
plt.show()

# %%
# Visualize Modeling for Horizontal BPMs
Center = np.array(Center)
Stddev = np.array(Stddev)
print(Center)

x_model = model(*Center, N_turns)
diff = BPMx0[initial: N_turns//2 + initial] - x_model[:N_turns//2] + BPMx0_mean
interval = 500#N_turns//2
initial = 35

plt.plot(BPMx0[initial: interval + initial], label = "data")
plt.plot(x_model[:interval], label = "model", alpha = .75)
plt.plot(diff[:interval], label = "difference", alpha = .5)

plt.legend()
plt.show()
# Out:
# [ 2.71623822e+00 -2.61843665e-01  2.93069539e+00  2.35360212e-01
#   1.91786101e-03  1.19825581e-03  7.90284560e-04  8.60784115e-04
#   4.89595977e-01]

# %%
# Initial conditions for Vertical BPMs
BPMY0 = np.abs(fft.rfft(BPMy[0])[1:])
BPMy0_Tune_scipy = Omega[np.argmax(BPMY0)]
pinitials = [BPMy[0, 0], 0.0, np.mean(BPMy[0]), BPMy0_Tune_scipy, 0.0,  0.0, 0, 1e-2, 0.5]
p_step = [1e-3, 1e-3, 1e-3, 5e-7, 0, 0, 0, 0, 0]
sinitials = [1e-2, 0e-2]
s_step = [2e-4, 0e-3]
initial = 535

pinitials[4] = 0.0018
pinitials[5] = 0.0006
pinitials[6] = 0.00073
pinitials[7] = 1e-2
pinitials[8] = 1
p_step[4] = 1e-5
p_step[5] = 1e-5
p_step[6] = 1e-4
p_step[7] = 1e-4
p_step[8] = 3e-2
N_iter = 150000

# Run MCMCMH Simulation for Vertical BPMs
begin = time.time()
# parr : iters x 11; sarr = iters x 2
parr, sarr = metropolis_hastings(log_likelihood, BPMy0[initial: ], N_iter, 
                              pinitials, p_step, sinitials, s_step)
end = time.time()
print("Time elapsed for full model:", end - begin)
# Out:
# Time elapsed for full model: 27.980292081832886

# %%
# Look at how variables change with # iterations
nrow = 3
ncol = 3
Theta_names = [r"$y_0$", r"$P_y$", r"$y_c$", r"$\nu_y$", r"$\epsilon_{SR}$", 
              r"$\epsilon_{NL}$", r"$\epsilon_E$", r"$\nu_s$", r"$\phi_s$"]
N_var = len(Theta_names)
N_iter = len(parr)
fig, Ax = plt.subplots(nrow, ncol*2, gridspec_kw = {'width_ratios':[5, 1]*ncol}, figsize=(12, 8))
fig.suptitle('Full Model')
split = N_iter//2
x_iter = np.linspace(0, N_iter//1000, N_iter)
Center = []
Stddev = []

for i in range(nrow):
    for j in range(ncol):
        if i*ncol + j >= N_var:
            break
        target = parr.T[i*ncol + j]
        Ax[i][j*2].set_xlabel("Thousand Iterations")
        Ax[i][j*2].set_ylabel(Theta_names[i*ncol + j])
        Ax[i][j*2].plot(x_iter, target)
        Ax[i][j*2].axvspan(split/1000, N_iter/1000, alpha = 0.1, color = 'c')
        Ax[i][j*2].axvline(split/1000, color = 'c', alpha = 0.1)
        center, stddev = np.average(target[split:]), np.std(target[split:])
        Center.append(center)
        Stddev.append(stddev)
        
        hist_data,_,_ = Ax[i][j*2 + 1].hist(target[split:], orientation='horizontal', density=True, color='c', bins=7)
        Ax[i][j*2 + 1].set_xlim([0, np.max(hist_data)*1.1])
        Ax[i][j*2 + 1].set_ylim([np.min(target), np.max(target)])
        Ax[i][j*2 + 1].get_yaxis().set_visible(False)
        
        
plt.subplots_adjust(wspace=0.0)
plt.show()

# %%
# Visualize Modeling for Vertical BPMs
Center = np.array(Center)
Stddev = np.array(Stddev)
print(Center)

y_model = model(*Center, N_turns)
interval = 500#N_turns//2
initial = 535
diff = BPMy0[initial:] - y_model[:len(BPMy0[initial:])] + np.mean(BPMy[0])

plt.plot(BPMy0[initial: interval + initial], label = "data")
plt.plot(y_model[:interval], label = "model", alpha = .75)
plt.plot(diff[:interval], label = "difference", alpha = .5)

plt.legend()
plt.show()
# Out:
# [ 5.61067536e+00 -5.20151889e-01  5.99951804e+00  2.28977312e-01
#   1.55601174e-03  1.01287839e-03  2.59929136e-03  1.33742263e-03
#   3.02805509e+00]

# %%
# Not the full circumference and only horizontal direction;
#  Saves (MaxBPM/(2*N_BPMs)) of time
# Made it so that this cell only needs to be ran once even after shutting down notebook
# If want to run again to regenerate Amplitude function DELETE FILES BEFORE RERUNNING
filenamex_mean = "Theta_BPMx_mean_Data3_200K"
filenamex_err = "Theta_BPMx_err_Data3_200K"
MaxBPM = 50
for i in range(MaxBPM):
    BPMXi = np.abs(fft.rfft(BPMx[i])[1:])
    BPMxi_Tune_scipy = Omega[np.argmax(BPMXi)]
    pinitials_x = [BPMx[i, 0], 0.0, np.mean(BPMx[i]), BPMxi_Tune_scipy, 1.8e-3,  6e-4, 7.3e-4, 1e-2, 1]
    p_step = [1e-3, 1e-3, 1e-3, 5e-7, 1e-5, 1e-5, 1e-4, 1e-4, 3e-2]
    sinitials = [1e-2, 0e-2]
    s_step = [2e-4, 0e-3]
    initial_x = 35
    N_iter = 200000
    begin = time.time()
    # parr : iters x 11; sarr = iters x 2
    parr, sarr = metropolis_hastings(log_likelihood, BPMx[i, initial_x: N_turns//2 + initial_x], N_iter, 
                                  pinitials_x, p_step, sinitials, s_step)
    end = time.time()
    print("Time elapsed for horizontal BPM %d:"%(i + 1), end - begin)
    with open(filenamex_mean, 'a') as csvfilex_mean:
        writerx_mean = csv.writer(csvfilex_mean, delimiter=',')
        writerx_mean.writerow(np.mean(parr.T[:, N_iter//2:], axis = 1))
    with open(filenamex_err, 'a') as csvfilex_err:
        writerx_err = csv.writer(csvfilex_err, delimiter=',')
        writerx_err.writerow(np.std(parr.T[:, N_iter//2:], axis = 1))
# Out:
# Time elapsed for horizontal BPM 1: 60.65240025520325
# Time elapsed for horizontal BPM 2: 79.86667609214783
# Time elapsed for horizontal BPM 3: 50.09631109237671
# Time elapsed for horizontal BPM 4: 40.07906103134155
# Time elapsed for horizontal BPM 5: 39.48184871673584
# Time elapsed for horizontal BPM 6: 41.31478214263916
# Time elapsed for horizontal BPM 7: 40.81493782997131
# Time elapsed for horizontal BPM 8: 45.286813259124756
# Time elapsed for horizontal BPM 9: 41.908207654953
# Time elapsed for horizontal BPM 10: 41.52808690071106
# Time elapsed for horizontal BPM 11: 38.642879009246826
# Time elapsed for horizontal BPM 12: 42.899173974990845
# Time elapsed for horizontal BPM 13: 40.578351974487305
# Time elapsed for horizontal BPM 14: 41.124128103256226
# Time elapsed for horizontal BPM 15: 41.7175350189209
# Time elapsed for horizontal BPM 16: 58.35174608230591
# Time elapsed for horizontal BPM 17: 43.169965744018555
# Time elapsed for horizontal BPM 18: 39.306907176971436
# Time elapsed for horizontal BPM 19: 41.10303783416748
# Time elapsed for horizontal BPM 20: 43.51359295845032
# Time elapsed for horizontal BPM 21: 41.98811483383179
# Time elapsed for horizontal BPM 22: 42.93913507461548
# Time elapsed for horizontal BPM 23: 45.46423697471619
# Time elapsed for horizontal BPM 24: 49.34950017929077
# Time elapsed for horizontal BPM 25: 38.301522970199585
# Time elapsed for horizontal BPM 26: 40.74274778366089
# Time elapsed for horizontal BPM 27: 39.34660005569458
# Time elapsed for horizontal BPM 28: 52.52825474739075
# Time elapsed for horizontal BPM 29: 68.08012175559998
# Time elapsed for horizontal BPM 30: 42.25143098831177
# Time elapsed for horizontal BPM 31: 39.839558124542236
# Time elapsed for horizontal BPM 32: 40.547723054885864
# Time elapsed for horizontal BPM 33: 46.89942193031311
# Time elapsed for horizontal BPM 34: 41.2322199344635
# Time elapsed for horizontal BPM 35: 41.16503429412842
# Time elapsed for horizontal BPM 36: 42.91225290298462
# Time elapsed for horizontal BPM 37: 40.97961115837097
# Time elapsed for horizontal BPM 38: 39.6954779624939
# Time elapsed for horizontal BPM 39: 39.59943914413452
# Time elapsed for horizontal BPM 40: 46.973686933517456
# Time elapsed for horizontal BPM 41: 51.85622501373291
# Time elapsed for horizontal BPM 42: 45.62047481536865
# Time elapsed for horizontal BPM 43: 48.152714014053345
# Time elapsed for horizontal BPM 44: 45.75571417808533
# Time elapsed for horizontal BPM 45: 41.85761904716492
# Time elapsed for horizontal BPM 46: 41.86043381690979
# Time elapsed for horizontal BPM 47: 52.61973023414612
# Time elapsed for horizontal BPM 48: 45.48934602737427
# Time elapsed for horizontal BPM 49: 45.14136505126953
# Time elapsed for horizontal BPM 50: 49.73672699928284

# %%
# Run the following two cells if you already have data
def Jbeta(X, Px, N_BPMs, Bad_bpms):
    res = X**2 + Px**2

    # Get rid of bad bpms
    for i in Bad_bpms:
        # Look for the nearest good bpm neighbors and take the average:
        lo, hi = i, i
        while lo in Bad_bpms: 
            lo -= 1
            if lo < 0: lo = N_BPMs - 1
        while hi in Bad_bpms: 
            hi += 1
            if hi >= N_BPMs: hi = 0
        res[i] = (res[lo] + res[hi])/2
    return res

#Error Propagation
def Jbeta_error(X, Px, X_err, Px_err, N_BPMs, Bad_bpms, err_lim):
    A = np.sqrt(Jbeta(X, Px, N_BPMs, Bad_bpms))
    error = X_err**2*(X/A)**2 + Px_err**2*(Px/A)**2
    LargeErrorBPM = np.zeros(len(X))
    for i in range(len(error)):
        if error[i] > err_lim:
            LargeErrorBPM[i] = 1
    return np.sqrt(error), LargeErrorBPM

# %%
filenamex_mean = "Theta_BPMx_mean_Data3_200K"
filenamex_err = "Theta_BPMx_err_Data3_200K"
MaxBPM = 50

# Visualize Amplitude function with Error Bars
with open(filenamex_mean, newline = "") as csvfilex_mean:
    Theta_final_x = np.array(list(csv.reader(csvfilex_mean, delimiter=',')), dtype=float)
with open(filenamex_err, newline = "") as csvfilex_err:
    Theta_final_x_err = np.array(list(csv.reader(csvfilex_err, delimiter=',')), dtype=float)

X, Px = Theta_final_x.T[:2]
X_err, Px_err = Theta_final_x_err.T[:2]
print(X_err[27:29], Px_err[27:29])
err_lim = .2
Bad_BPMx = Bad_Bpms(BPMx_Tune_Map[:MaxBPM], nu_x, MaxBPM)

BPMx_Jbeta_Map = np.sqrt(Jbeta((X - np.mean(BPMx[:MaxBPM], axis = 1)), Px, MaxBPM, Bad_BPMx[:MaxBPM]))
BPMx_Jbeta_Map_err, LargeErrorBPMx = Jbeta_error(X, Px, X_err, Px_err, MaxBPM, Bad_BPMx[:MaxBPM], err_lim)

fig, ax = plt.subplots(figsize = (15, 6))
BPMx_Jbeta_Map_err_plot = np.copy(BPMx_Jbeta_Map_err)
for i, status in enumerate(LargeErrorBPMx):
    if status == 1: BPMx_Jbeta_Map_err_plot[i] = err_lim
ax.errorbar(S_xbpms[0, :MaxBPM], BPMx_Jbeta_Map, yerr = BPMx_Jbeta_Map_err_plot, color = 'k', ecolor = 'r', capsize = 2)
plt.axvline(x = S_xbpms[0, 27])
plt.axvline(x = S_xbpms[0, 28])
ax.set_xlabel("s")
ax.set_ylabel(r"$\sqrt{J\beta_x}$")
ax.set_title(r"Amplitude measurements of Horizonal BPMS")
plt.show()
# Out:
# [0.00847238 0.01039547] [0.01009838 0.01346568]

# %%
filenamex_mean2 = "Theta_BPMx_mean_Data1_100K_27-28"
filenamex_err2 = "Theta_BPMx_err_Data1_100K_27-28"
N_iter = 96
for n in range(N_iter):
    for i in range(27, 29):
        BPMXi = np.abs(fft.rfft(BPMx[i])[1:])
        BPMxi_Tune_scipy = Omega[np.argmax(BPMXi)]
        pinitials_x = [BPMx[i, 0], 0.0, np.mean(BPMx[i]), BPMxi_Tune_scipy, 1.8e-3,  6e-4, 7.3e-4, 1e-2, 1]
        p_step = [1e-3, 1e-3, 1e-3, 5e-7, 1e-5, 1e-5, 1e-4, 1e-4, 3e-2]
        sinitials = [1e-2, 0e-2]
        s_step = [2e-4, 0e-3]
        initial_x = 35
        N_iter = 100000
        begin = time.time()
        # parr : iters x 11; sarr = iters x 2
        parr, sarr = metropolis_hastings(log_likelihood, BPMx[i, initial_x: N_turns//2 + initial_x], N_iter, 
                                      pinitials_x, p_step, sinitials, s_step)
        end = time.time()
        print("Time elapsed for horizontal BPM %d on iteration %d:"%(i + 1, n + 1), end - begin)
        with open(filenamex_mean2, 'a') as csvfilex_mean:
            writerx_mean = csv.writer(csvfilex_mean, delimiter=',')
            writerx_mean.writerow(np.mean(parr.T[:, N_iter//2:], axis = 1))
        with open(filenamex_err2, 'a') as csvfilex_err:
            writerx_err = csv.writer(csvfilex_err, delimiter=',')
            writerx_err.writerow(np.std(parr.T[:, N_iter//2:], axis = 1))
# Out:
# Time elapsed for horizontal BPM 28 on iteration 1: 15.972800016403198
# Time elapsed for horizontal BPM 29 on iteration 1: 16.870523929595947
# Time elapsed for horizontal BPM 28 on iteration 2: 15.602526903152466
# Time elapsed for horizontal BPM 29 on iteration 2: 15.254020929336548
# Time elapsed for horizontal BPM 28 on iteration 3: 16.842314958572388
# Time elapsed for horizontal BPM 29 on iteration 3: 14.90148401260376
# Time elapsed for horizontal BPM 28 on iteration 4: 15.33434796333313
# Time elapsed for horizontal BPM 29 on iteration 4: 16.219788789749146
# Time elapsed for horizontal BPM 28 on iteration 5: 15.942047119140625
# Time elapsed for horizontal BPM 29 on iteration 5: 17.06642723083496
# Time elapsed for horizontal BPM 28 on iteration 6: 15.164773941040039
# Time elapsed for horizontal BPM 29 on iteration 6: 14.643407821655273
# Time elapsed for horizontal BPM 28 on iteration 7: 15.400148868560791
# Time elapsed for horizontal BPM 29 on iteration 7: 15.362771987915039
# Time elapsed for horizontal BPM 28 on iteration 8: 14.57427191734314
# Time elapsed for horizontal BPM 29 on iteration 8: 14.722112894058228
# Time elapsed for horizontal BPM 28 on iteration 9: 17.06899619102478
# Time elapsed for horizontal BPM 29 on iteration 9: 15.872439861297607
# Time elapsed for horizontal BPM 28 on iteration 10: 14.884548902511597
# Time elapsed for horizontal BPM 29 on iteration 10: 15.153414011001587
# Time elapsed for horizontal BPM 28 on iteration 11: 18.881094932556152
# Time elapsed for horizontal BPM 29 on iteration 11: 14.730126857757568
# Time elapsed for horizontal BPM 28 on iteration 12: 15.166615009307861
# Time elapsed for horizontal BPM 29 on iteration 12: 17.009625911712646
# Time elapsed for horizontal BPM 28 on iteration 13: 17.063173055648804
# Time elapsed for horizontal BPM 29 on iteration 13: 16.335585117340088
# Time elapsed for horizontal BPM 28 on iteration 14: 16.151598930358887
# Time elapsed for horizontal BPM 29 on iteration 14: 14.695931196212769
# Time elapsed for horizontal BPM 28 on iteration 15: 20.792628288269043
# Time elapsed for horizontal BPM 29 on iteration 15: 20.858724117279053
# Time elapsed for horizontal BPM 28 on iteration 16: 15.517431020736694
# /var/folders/r3/ccbllzdn2pb3wzn_b988y1n80000gp/T/ipykernel_17849/2432908124.py:24: RuntimeWarning: overflow encountered in multiply
#   return -np.sum(diff*diff/2.0/ss) - np.sum(np.log(np.sqrt(ss)))#*len(diff)
# /var/folders/r3/ccbllzdn2pb3wzn_b988y1n80000gp/T/ipykernel_17849/2432908124.py:24: RuntimeWarning: overflow encountered in divide
#   return -np.sum(diff*diff/2.0/ss) - np.sum(np.log(np.sqrt(ss)))#*len(diff)
# Time elapsed for horizontal BPM 29 on iteration 16: 16.623316049575806
# Time elapsed for horizontal BPM 28 on iteration 17: 14.407385110855103
# Time elapsed for horizontal BPM 29 on iteration 17: 14.555113077163696
# Time elapsed for horizontal BPM 28 on iteration 18: 14.422031879425049
# /var/folders/r3/ccbllzdn2pb3wzn_b988y1n80000gp/T/ipykernel_17849/2432908124.py:15: RuntimeWarning: overflow encountered in exp
#   decay = np.exp(-(alpha**2 - alpha02)/2 - (eps_nl*turns)**2 - eps_sr*turns)
# Time elapsed for horizontal BPM 29 on iteration 18: 16.892688751220703
# Time elapsed for horizontal BPM 28 on iteration 19: 20.41285991668701
# Time elapsed for horizontal BPM 29 on iteration 19: 16.059781312942505
# Time elapsed for horizontal BPM 28 on iteration 20: 15.282685995101929
# Time elapsed for horizontal BPM 29 on iteration 20: 14.584274291992188
# Time elapsed for horizontal BPM 28 on iteration 21: 14.746802806854248
# Time elapsed for horizontal BPM 29 on iteration 21: 16.735841035842896
# Time elapsed for horizontal BPM 28 on iteration 22: 17.187013149261475
# Time elapsed for horizontal BPM 29 on iteration 22: 20.070491790771484
# Time elapsed for horizontal BPM 28 on iteration 23: 18.757934093475342
# Time elapsed for horizontal BPM 29 on iteration 23: 20.021473169326782
# Time elapsed for horizontal BPM 28 on iteration 24: 20.683115005493164
# Time elapsed for horizontal BPM 29 on iteration 24: 17.937456130981445
# Time elapsed for horizontal BPM 28 on iteration 25: 17.97434115409851
# Time elapsed for horizontal BPM 29 on iteration 25: 25.041300058364868
# Time elapsed for horizontal BPM 28 on iteration 26: 23.112453937530518
# Time elapsed for horizontal BPM 29 on iteration 26: 21.44590997695923
# Time elapsed for horizontal BPM 28 on iteration 27: 21.176374912261963
# Time elapsed for horizontal BPM 29 on iteration 27: 20.88860583305359
# Time elapsed for horizontal BPM 28 on iteration 28: 15.902227878570557
# Time elapsed for horizontal BPM 29 on iteration 28: 19.871612310409546
# Time elapsed for horizontal BPM 28 on iteration 29: 15.6007719039917
# Time elapsed for horizontal BPM 29 on iteration 29: 15.785102128982544
# Time elapsed for horizontal BPM 28 on iteration 30: 15.236128091812134
# Time elapsed for horizontal BPM 29 on iteration 30: 15.824903011322021
# Time elapsed for horizontal BPM 28 on iteration 31: 14.343284130096436
# Time elapsed for horizontal BPM 29 on iteration 31: 14.85861873626709
# Time elapsed for horizontal BPM 28 on iteration 32: 16.243808031082153
# Time elapsed for horizontal BPM 29 on iteration 32: 15.87715196609497
# Time elapsed for horizontal BPM 28 on iteration 33: 14.348212957382202
# Time elapsed for horizontal BPM 29 on iteration 33: 14.711803913116455
# Time elapsed for horizontal BPM 28 on iteration 34: 20.120563983917236
# Time elapsed for horizontal BPM 29 on iteration 34: 16.088254928588867
# Time elapsed for horizontal BPM 28 on iteration 35: 14.461935043334961
# Time elapsed for horizontal BPM 29 on iteration 35: 15.443557024002075
# Time elapsed for horizontal BPM 28 on iteration 36: 15.772979974746704
# Time elapsed for horizontal BPM 29 on iteration 36: 20.138108253479004
# Time elapsed for horizontal BPM 28 on iteration 37: 20.40654182434082
# Time elapsed for horizontal BPM 29 on iteration 37: 16.2044038772583
# Time elapsed for horizontal BPM 28 on iteration 38: 30.719116926193237
# Time elapsed for horizontal BPM 29 on iteration 38: 39.313775062561035
# Time elapsed for horizontal BPM 28 on iteration 39: 43.662485122680664
# Time elapsed for horizontal BPM 29 on iteration 39: 22.352985858917236
# Time elapsed for horizontal BPM 28 on iteration 40: 20.677382946014404
# Time elapsed for horizontal BPM 29 on iteration 40: 23.045323848724365
# Time elapsed for horizontal BPM 28 on iteration 41: 19.088438987731934
# Time elapsed for horizontal BPM 29 on iteration 41: 18.576433897018433
# Time elapsed for horizontal BPM 28 on iteration 42: 21.108292818069458
# Time elapsed for horizontal BPM 29 on iteration 42: 18.411789894104004
# Time elapsed for horizontal BPM 28 on iteration 43: 17.17610001564026
# Time elapsed for horizontal BPM 29 on iteration 43: 17.67978286743164
# Time elapsed for horizontal BPM 28 on iteration 44: 14.656944990158081
# Time elapsed for horizontal BPM 29 on iteration 44: 14.677994966506958
# Time elapsed for horizontal BPM 28 on iteration 45: 14.945070266723633
# Time elapsed for horizontal BPM 29 on iteration 45: 15.88727593421936
# Time elapsed for horizontal BPM 28 on iteration 46: 14.950240135192871
# Time elapsed for horizontal BPM 29 on iteration 46: 15.045206069946289
# Time elapsed for horizontal BPM 28 on iteration 47: 14.572437047958374
# Time elapsed for horizontal BPM 29 on iteration 47: 15.886873960494995
# Time elapsed for horizontal BPM 28 on iteration 48: 14.653774738311768
# Time elapsed for horizontal BPM 29 on iteration 48: 17.912771940231323
# Time elapsed for horizontal BPM 28 on iteration 49: 18.453948974609375
# Time elapsed for horizontal BPM 29 on iteration 49: 21.99169087409973
# Time elapsed for horizontal BPM 28 on iteration 50: 20.991875886917114
# Time elapsed for horizontal BPM 29 on iteration 50: 20.205318927764893
# Time elapsed for horizontal BPM 28 on iteration 51: 14.840309143066406
# Time elapsed for horizontal BPM 29 on iteration 51: 16.747677087783813
# Time elapsed for horizontal BPM 28 on iteration 52: 18.193366050720215
# Time elapsed for horizontal BPM 29 on iteration 52: 19.00590205192566
# Time elapsed for horizontal BPM 28 on iteration 53: 17.22379183769226
# Time elapsed for horizontal BPM 29 on iteration 53: 22.482184886932373
# Time elapsed for horizontal BPM 28 on iteration 54: 20.981175899505615
# Time elapsed for horizontal BPM 29 on iteration 54: 19.817546129226685
# Time elapsed for horizontal BPM 28 on iteration 55: 21.21877408027649
# Time elapsed for horizontal BPM 29 on iteration 55: 23.870434999465942
# Time elapsed for horizontal BPM 28 on iteration 56: 22.746426105499268
# Time elapsed for horizontal BPM 29 on iteration 56: 19.157147884368896
# Time elapsed for horizontal BPM 28 on iteration 57: 17.75348401069641
# Time elapsed for horizontal BPM 29 on iteration 57: 16.516657829284668
# Time elapsed for horizontal BPM 28 on iteration 58: 17.374714851379395
# Time elapsed for horizontal BPM 29 on iteration 58: 19.49227213859558
# Time elapsed for horizontal BPM 28 on iteration 59: 17.30695915222168
# Time elapsed for horizontal BPM 29 on iteration 59: 15.47563910484314
# Time elapsed for horizontal BPM 28 on iteration 60: 20.902841091156006
# Time elapsed for horizontal BPM 29 on iteration 60: 17.71547293663025
# Time elapsed for horizontal BPM 28 on iteration 61: 15.267956972122192
# Time elapsed for horizontal BPM 29 on iteration 61: 16.878902912139893
# Time elapsed for horizontal BPM 28 on iteration 62: 24.789581060409546
# Time elapsed for horizontal BPM 29 on iteration 62: 21.036999225616455
# Time elapsed for horizontal BPM 28 on iteration 63: 25.265740871429443
# Time elapsed for horizontal BPM 29 on iteration 63: 18.173962116241455
# Time elapsed for horizontal BPM 28 on iteration 64: 16.741139888763428
# Time elapsed for horizontal BPM 29 on iteration 64: 16.706475019454956
# Time elapsed for horizontal BPM 28 on iteration 65: 17.400919198989868
# Time elapsed for horizontal BPM 29 on iteration 65: 18.086386919021606
# Time elapsed for horizontal BPM 28 on iteration 66: 25.912516117095947
# Time elapsed for horizontal BPM 29 on iteration 66: 38.18028426170349
# Time elapsed for horizontal BPM 28 on iteration 67: 1827.2067217826843
# Time elapsed for horizontal BPM 29 on iteration 67: 40.904136180877686
# Time elapsed for horizontal BPM 28 on iteration 68: 28.950122117996216
# Time elapsed for horizontal BPM 29 on iteration 68: 26.13104510307312
# Time elapsed for horizontal BPM 28 on iteration 69: 27.48572587966919
# Time elapsed for horizontal BPM 29 on iteration 69: 26.171998977661133
# Time elapsed for horizontal BPM 28 on iteration 70: 26.55122399330139
# Time elapsed for horizontal BPM 29 on iteration 70: 23.577529668807983
# Time elapsed for horizontal BPM 28 on iteration 71: 19.838388919830322
# Time elapsed for horizontal BPM 29 on iteration 71: 19.91984724998474
# Time elapsed for horizontal BPM 28 on iteration 72: 18.92873501777649
# Time elapsed for horizontal BPM 29 on iteration 72: 19.11346673965454
# Time elapsed for horizontal BPM 28 on iteration 73: 19.57516598701477
# Time elapsed for horizontal BPM 29 on iteration 73: 20.070207834243774
# Time elapsed for horizontal BPM 28 on iteration 74: 18.233702898025513
# Time elapsed for horizontal BPM 29 on iteration 74: 19.11498498916626
# Time elapsed for horizontal BPM 28 on iteration 75: 17.741169929504395
# Time elapsed for horizontal BPM 29 on iteration 75: 18.653042793273926
# Time elapsed for horizontal BPM 28 on iteration 76: 18.003380060195923
# Time elapsed for horizontal BPM 29 on iteration 76: 19.104743242263794
# Time elapsed for horizontal BPM 28 on iteration 77: 18.43848180770874
# Time elapsed for horizontal BPM 29 on iteration 77: 1831.3789901733398
# Time elapsed for horizontal BPM 28 on iteration 78: 27.806374073028564
# Time elapsed for horizontal BPM 29 on iteration 78: 25.696076154708862
# Time elapsed for horizontal BPM 28 on iteration 79: 26.08575677871704
# Time elapsed for horizontal BPM 29 on iteration 79: 28.3674738407135
# Time elapsed for horizontal BPM 28 on iteration 80: 49.26211905479431
# Time elapsed for horizontal BPM 29 on iteration 80: 43.69824409484863
# Time elapsed for horizontal BPM 28 on iteration 81: 41.32132411003113
# Time elapsed for horizontal BPM 29 on iteration 81: 38.47356200218201
# Time elapsed for horizontal BPM 28 on iteration 82: 26.599891185760498
# Time elapsed for horizontal BPM 29 on iteration 82: 32.79266285896301
# Time elapsed for horizontal BPM 28 on iteration 83: 23.673512935638428
# Time elapsed for horizontal BPM 29 on iteration 83: 22.057912826538086
# Time elapsed for horizontal BPM 28 on iteration 84: 25.248951196670532
# Time elapsed for horizontal BPM 29 on iteration 84: 20.296118021011353
# Time elapsed for horizontal BPM 28 on iteration 85: 21.16559100151062
# Time elapsed for horizontal BPM 29 on iteration 85: 23.018277883529663
# Time elapsed for horizontal BPM 28 on iteration 86: 24.053210973739624
# Time elapsed for horizontal BPM 29 on iteration 86: 21.681671857833862
# Time elapsed for horizontal BPM 28 on iteration 87: 26.468810081481934
# Time elapsed for horizontal BPM 29 on iteration 87: 27.814296007156372
# Time elapsed for horizontal BPM 28 on iteration 88: 33.89884281158447
# Time elapsed for horizontal BPM 29 on iteration 88: 30.111037969589233
# Time elapsed for horizontal BPM 28 on iteration 89: 20.976410150527954
# Time elapsed for horizontal BPM 29 on iteration 89: 16.652387142181396
# Time elapsed for horizontal BPM 28 on iteration 90: 16.548617362976074
# Time elapsed for horizontal BPM 29 on iteration 90: 17.756659984588623
# Time elapsed for horizontal BPM 28 on iteration 91: 21.04104495048523
# Time elapsed for horizontal BPM 29 on iteration 91: 18.12035298347473
# Time elapsed for horizontal BPM 28 on iteration 92: 20.45296001434326
# Time elapsed for horizontal BPM 29 on iteration 92: 20.479036808013916
# Time elapsed for horizontal BPM 28 on iteration 93: 15.472953081130981
# Time elapsed for horizontal BPM 29 on iteration 93: 16.4487202167511
# Time elapsed for horizontal BPM 28 on iteration 94: 17.44862389564514
# Time elapsed for horizontal BPM 29 on iteration 94: 19.235414028167725
# Time elapsed for horizontal BPM 28 on iteration 95: 19.722228050231934
# Time elapsed for horizontal BPM 29 on iteration 95: 23.46731686592102
# Time elapsed for horizontal BPM 28 on iteration 96: 18.985599040985107
# Time elapsed for horizontal BPM 29 on iteration 96: 21.023746013641357

# %%
filenamex_mean2 = "Theta_BPMx_mean_Data1_100K_27-28"
filenamex_err2 = "Theta_BPMx_err_Data1_100K_27-28"

# Visualize Amplitude function with Error Bars
with open(filenamex_mean2, newline = "") as csvfilex_mean:
    csvfilex_mean_data = list(csv.reader(csvfilex_mean, delimiter=','))
    Theta_final_x_27 = np.array((csvfilex_mean_data), dtype=float)[::2]
    Theta_final_x_28 = np.array((csvfilex_mean_data), dtype=float)[1::2]
with open(filenamex_err2, newline = "") as csvfilex_err:
    csvfilex_err_data = list(csv.reader(csvfilex_err, delimiter=','))
    Theta_final_x_err_27 = np.array((csvfilex_err_data), dtype=float)[::2]
    Theta_final_x_err_28 = np.array((csvfilex_err_data), dtype=float)[1::2]

X_27, Px_27 = np.mean(Theta_final_x_27.T[:2], axis = 1)
X_28, Px_28 = np.mean(Theta_final_x_28.T[:2], axis = 1)
X_err_27, Px_err_27 = np.std(Theta_final_x_err_27.T[:2], axis = 1)
X_err_28, Px_err_28 = np.std(Theta_final_x_err_28.T[:2], axis = 1)
# X_err_27, Px_err_27 = np.mean(Theta_final_x_err_27.T[:2], axis = 1)
# X_err_28, Px_err_28 = np.mean(Theta_final_x_err_28.T[:2], axis = 1)

A_27 = np.sqrt((X_27 - np.mean(BPMx[27]))**2 + Px_27**2)
A_28 = np.sqrt((X_28 - np.mean(BPMx[28]))**2 + Px_28**2)
BPMx_Jbeta_Map[27:29] = A_27, A_28
BPMx_Jbeta_Map_err[27] = np.sqrt(X_err_27**2*(X_27/A_27)**2 + Px_err_27**2*(Px_27/A_27)**2)
BPMx_Jbeta_Map_err[28] = np.sqrt(X_err_28**2*(X_28/A_28)**2 + Px_err_28**2*(Px_28/A_28)**2)

fig, ax = plt.subplots(figsize = (15, 6))
BPMx_Jbeta_Map_err_plot = np.copy(BPMx_Jbeta_Map_err)
for i, status in enumerate(LargeErrorBPMx):
    if status == 1: BPMx_Jbeta_Map_err_plot[i] = err_lim
ax.errorbar(S_xbpms[0, :MaxBPM], BPMx_Jbeta_Map, yerr = BPMx_Jbeta_Map_err_plot, color = 'k', ecolor = 'r', capsize = 2)
# plt.axvline(x = S_xbpms[0, 27])
# plt.axvline(x = S_xbpms[0, 28])
ax.set_xlabel("s")
ax.set_ylabel(r"$\sqrt{J\beta_x}$")
ax.set_title(r"Amplitude measurements of Horizonal BPMS")
plt.show()

# %% [markdown]
# # Betatron Function around IP8

# %% [markdown]
# Determine $\alpha$ at g7-bx:
#
# \begin{equation*}
# M_{drift} =
# \begin{bmatrix}
# C & S\\
# C' & S'
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 & L\\
# 0 & 1
# \end{bmatrix}
# \end{equation*}
#
# \begin{equation*}
# \Rightarrow
# M_{twiss} =
# \begin{bmatrix}
# 1 & -2L & L^2 \\
# 0 & 1 & -L \\
# 0 & 0 & 1
# \end{bmatrix}
# \end{equation*}
#
# Between BPM 27 (1) and BPM 28 (2):
# \begin{equation*}
# \begin{bmatrix}
# \beta_2 \\
# \alpha_1 \\
# \gamma_1 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 & -2L & L^2 \\
# 0 & 1 & -L \\
# 0 & 0 & 1
# \end{bmatrix}
# \begin{bmatrix}
# \beta_1 \\
# \alpha_1 \\
# \gamma_1 \\
# \end{bmatrix}
# \end{equation*}
#
# $\Rightarrow \beta_2 = \beta_1 - 2L\alpha_i + L^2 \gamma_i$\
# $\Rightarrow \alpha_1 = \frac{\beta_1}{L} \pm \sqrt{\frac{\beta_1\beta_2}{L^2} - 1}$

# %% [markdown]
# $\alpha$ can also be derived from $\beta^*$ parabola formula:\
# $\beta(s) = \beta^* + \frac{(s - s^*)^2}{\beta^*}$\
# $\beta'(s) = \frac{2(s - s^*)}{\beta^*}$\
# $\alpha_{s} = -\frac{\beta'(s)}{2} = \frac{(s^* - s)}{\beta^*}$\
# $\alpha_{g7-bx} = (s^* - s_{g7-bx})/\beta^*$
#
# Combining the two results for $\alpha$:\
# $\alpha_{g7-bx} = \frac{s^* - s_{g7-bx}}{\beta^*} = \frac{\beta(s_{g7-bx})}{L} + \sqrt{\frac{\beta_1\beta_2}{L^2} - 1}$

# %% [markdown]
# Now solve for three nonlinear equations and three unknowns: $\beta^*, s^*, J$\
# Using:\
# $\beta = \frac{A}{J}$\
# 0 = $\beta^* + (s_{g7-bx} - s^*)^2/\beta^* - \beta(s_{g7-bx})$\
# 0 = $\beta^* + (s_{g8-bx} - s^*)^2/\beta^* - \beta(s_{g8-bx})$\
# $\alpha_{g7-bx} = (s^* - s_{g7-bx})/\beta^*$\
# 0 = $\sqrt{\frac{\beta_1\beta_2}{L^2} - 1} - (\alpha_{g7-bx} - \beta(s_{g7-bx})/L_{27-28}))$
#
# This method uses only information from g7-bx and g8-bx.\
# It produces many solutions based on the guess of $\beta^*$ and J, so look at L2 error of each combination.\
# Use these results to get the uncertainty of J.

# %%
# Predict J const using MADx
s_MADx = []
Betax_MADx = []
with open('twiss.out_Au23-100GeV-e0-beta5') as output:
    Lines = output.readlines()
    for i, line in enumerate(Lines[48:]):
        Line = re.split("\s+", line)
        Line[1] = Line[1].replace('_', '-')[1:-1]
        if Line[1] in np.char.upper(Name_xbpms) or Line[1] == 'BI9-B3.1': # because it is BI9-BH3.1 in the measurement file
            s_MADx.append(float(Line[2]))
            Betax_MADx.append(float(Line[3]))

s_MADx = np.array(s_MADx)[:MaxBPM]
Betax_MADx = np.array(Betax_MADx)[:MaxBPM]
BetaArc = []
AmpArc = []
sArc = []
for i, name in enumerate(Name_xbpms[:MaxBPM]):
    if name[0] != 'g' and name[-4:-2] == "bh" and int(name[-2:]) >= 12:
        #print(name)
        BetaArc.append(Betax_MADx[i])
        AmpArc.append(BPMx_Jbeta_Map[i])
#         print(i, BPMx_Jbeta_Map[i], Name_xbpms[i])
        sArc.append(s_MADx[i])
        
BetaArc = np.array(BetaArc)[:MaxBPM]
AmpArc = np.array(AmpArc)[:MaxBPM]
J_MADx = (sum(AmpArc)/sum(BetaArc))
print(J_MADx)
# Out:
# 0.005444407461633673

# %%
# use Solver to solve 3 equations for 3 unknowns
s_g7_bx, s_g8_bx = S_xbpms[0, 27:29]
L27_28 = abs(s_g8_bx - s_g7_bx)
sIP8 = 639.445027949618

def f2(x):
    sstar, bstar, J = x
    b27, b28 = (BPMx_Jbeta_Map[27:29]/J)
    return np.array([
           bstar + (s_g7_bx - sstar)**2/bstar - b27, 
           bstar + (s_g8_bx - sstar)**2/bstar - b28,
           np.sqrt((b27*b28/L27_28**2 - 1)) - ((sstar - s_g7_bx)/bstar - b27/L27_28)])

#accuracy:
N_J = 100000

Jguess = np.linspace(.001, .005, N_J)

Err = np.zeros(N_J)
Sstar = np.zeros(N_J)
Bstar = np.zeros(N_J)
Jconst = np.zeros(N_J)
for j, J in enumerate(Jguess):
    sstar, bstar, jconst = optimize.fsolve(f2, [sIP8, .5, J])
    Err[j] = np.sqrt(np.sum((f2([sstar, bstar, jconst]))**2))
    Sstar[j] = sstar
    Bstar[j] = bstar
    Jconst[j] = jconst
    
plt.plot(Jconst, Err)
plt.xlabel("guess for J")
plt.ylabel("L2 error")
plt.show()

j_ind = np.argmin(Err)
sstar_LE, bstar_LE, jconst_LE = optimize.fsolve(f2, [sIP8, .5, Jguess[j_ind]])
print("Lowest error result")
display(Math(r"s^* = %f, \beta^* = %f, J = %f"%(sstar_LE, bstar_LE, jconst_LE)))
display(Math(r"\Delta s^* = %f"%(sstar - sIP8)))
# Out:
# /var/folders/r3/ccbllzdn2pb3wzn_b988y1n80000gp/T/ipykernel_17849/2742663067.py:12: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt((b27*b28/L27_28**2 - 1)) - ((sstar - s_g7_bx)/bstar - b27/L27_28)])
# Lowest error result
# $\displaystyle s^* = 639.383377, \beta^* = 0.481418, J = 0.002885$
# $\displaystyle \Delta s^* = -0.061784$

# %%
bins = 100
fig, axs = plt.subplots(1, 3, sharey = True, tight_layout=True, figsize = (10, 4))
plt.suptitle("Unweighted")
axs[0].hist(Sstar.flatten(), bins)
axs[1].hist(Bstar.flatten(), bins)
axs[2].hist(Jconst.flatten(), bins)
axs[0].set_ylabel("freq")
axs[0].set_title(r"$s^*$")
axs[1].set_title(r"$\beta^*$")
axs[2].set_title("J")
plt.show()
print("Stats:")

display(Math("\overline{s}^* = %f \pm %f"% (np.mean(Sstar), np.std(Sstar))))
display(Math(r"\overline{\beta}^* = %f \pm %f"% (np.mean(Bstar), np.std(Bstar))))
display(Math(r"\overline{J} = %f \pm %f"% (np.mean(Jconst), np.std(Jconst))))
display(Math(r"\Delta s^* = %f \pm %f"% (np.mean(Sstar) - sIP8, np.std(Sstar))))
# Out:
# Stats:
# $\displaystyle \overline{s}^* = 639.383452 \pm 0.002283$
# $\displaystyle \overline{\beta}^* = 0.480693 \pm 0.109424$
# $\displaystyle \overline{J} = 0.002879 \pm 0.000651$
# $\displaystyle \Delta s^* = -0.061576 \pm 0.002283$

# %%
fig, axs = plt.subplots(1, 3, tight_layout=True, figsize = (10, 4))
plt.suptitle("Weighted")
weight = 1/(Err.flatten() + 1e-10)
freq_Sstar_weight, bins_Sstar_weight, _ = axs[0].hist(Sstar.flatten(), bins, weights = weight)#, density = True)
freq_Bstar_weight, bins_Bstar_weight, _ = axs[1].hist(Bstar.flatten(), bins, weights = weight)#, density = True)
freq_Jconst_weight, bins_Jconst_weight, _ = axs[2].hist(Jconst.flatten(), bins, weights = weight)#, density = True)
axs[0].set_ylabel("weighted freq")
axs[0].set_title(r"$s^*$")
axs[1].set_title(r"$\beta^*$")
axs[2].set_title("J")
#axs[2].set_xlim([0, .1])
plt.show()

# Find mean and stddev of three plots
def weighted_avg_and_std(values, weights):
    """
    Return the weighted average and standard deviation.

    values, weights -- NumPy ndarrays with the same shape.
    """
    average = np.average(values, weights=weights)
    # Fast and numerically precise:
    variance = np.average((values-average)**2, weights=weights)
    return average, np.sqrt(variance)
print("Weighted Stats:")
sstar_avg_weighted, sstar_stddev_weighted = weighted_avg_and_std(bins_Sstar_weight[:-1], freq_Sstar_weight)
Bstar_avg_weighted, Bstar_stddev_weighted = weighted_avg_and_std(bins_Bstar_weight[:-1], freq_Bstar_weight)
Jconst_avg_weighted, Jconst_stddev_weighted = weighted_avg_and_std(bins_Jconst_weight[:-1], freq_Jconst_weight)
display(Math("\overline{s}^* = %f \pm %f"% (sstar_avg_weighted, sstar_stddev_weighted)))
display(Math(r"\overline{\beta}^* = %f \pm %f"% (Bstar_avg_weighted, Bstar_stddev_weighted)))
display(Math(r"\overline{J} = %f \pm %f"% (Jconst_avg_weighted, Jconst_stddev_weighted)))
display(Math(r"\Delta s^* = %f \pm %f"% (sstar_avg_weighted - sIP8, sstar_stddev_weighted)))
# Out:
# Weighted Stats:
# $\displaystyle \overline{s}^* = 639.382940 \pm 0.000080$
# $\displaystyle \overline{\beta}^* = 0.491127 \pm 0.109128$
# $\displaystyle \overline{J} = 0.002940 \pm 0.000648$
# $\displaystyle \Delta s^* = -0.062088 \pm 0.000080$

# %% [markdown]
# ## Error Propagation Calculation:
# ### On Betatron function:
# $\beta = \frac{A}{J}$\
# $\Rightarrow \sigma_{\beta}^2 = (\sigma_{A}\frac{\partial \beta}{\partial A})^2 + (\sigma_{J}\frac{\partial \beta}{\partial J})^2$\
# $\Rightarrow \sigma_{\beta} = \sqrt{(\sigma_{A}\frac{1}{J})^2 + (\sigma_{J}\frac{-A}{J^2})^2}$
#
# Then calculate partial derivatives of alpha:\
# $\alpha_{27} = \frac{\beta_{27}}{L} + \sqrt{\frac{\beta_{27}\beta_{28}}{L^2} - 1}$\
# $\Rightarrow \frac{\partial \alpha_{27}}{\partial \beta_{27}} = \frac{1}{L} + \frac{\beta_{28}}{2L^2\sqrt{\frac{\beta_{27}\beta_{28}}{L^2} - 1}}$\
# & $\frac{\partial \alpha_{27}}{\partial \beta_{28}} = \frac{\beta_{27}}{2L^2\sqrt{\frac{\beta_{27}\beta_{28}}{L^2} - 1}}$
#
# Using these, calculate error
# ### On $s^*$:
# $s^* = s_{g7-bx} + \frac{\alpha_{27}\beta_{27}}{\alpha_{27}^2 + 1}$\
# $\Rightarrow \frac{\partial s^*}{\partial \beta_{27}} = \frac{-\frac{\partial \alpha_{27}}{\partial \beta_{27}}\alpha_{27}^2\beta_{27} + {\frac{\partial \alpha_{27}}{\partial \beta_{27}}\beta_{27} + \alpha_{27}^3 + \alpha_{27}}}{(\alpha_{27}^2 + 1)^2}$\
# & $\frac{\partial s^*}{\partial \beta_{28}} = \frac{-\frac{\partial \alpha_{27}}{\partial \beta_{28}}\beta_{27}(\alpha_{27}^2 - 1)}{(\alpha_{27}^2 + 1)^2}$
#
# $\therefore \sigma_{s^*}^2 = (\sigma_{\beta_{27}}\frac{\partial s^*}{\partial \beta_{27}})^2 + (\sigma_{\beta_{28}}\frac{\partial s^*}{\partial \beta_{28}})^2$
#
# ### And $\beta^*$:
# $\beta^* = \frac{\beta_{27}}{\alpha_{27}^2 + 1}$\
# $\Rightarrow \frac{\partial \beta^*}{\partial \beta_{27}} = \frac{-2\frac{\partial \alpha_{27}}{\partial \beta_{27}}\alpha_{27}\beta_{27} + \alpha_{27}^2 + 1}{(\alpha_{27}^2 + 1)^2}$\
# & $\frac{\partial \beta^*}{\partial \beta_{28}} = \frac{-2\frac{\partial \alpha_{27}}{\partial \beta_{28}}\alpha_{27}\beta_{27}}{(\alpha_{27}^2 + 1)^2}$
#
# $\therefore \sigma_{\beta^*}^2 = (\sigma_{\beta_{27}}\frac{\partial \beta^*}{\partial \beta_{27}})^2 + (\sigma_{\beta_{28}}\frac{\partial \beta^*}{\partial \beta_{28}})^2$

# %%
def calc_parabola_vertex(x1, y1, x2, y2, x3, y3):
    denom = (x1-x2) * (x1-x3) * (x2-x3)
    A     = (x3 * (y2-y1) + x2 * (y1-y3) + x1 * (y3-y2)) / denom
    B     = (x3*x3 * (y1-y2) + x2*x2 * (y3-y1) + x1*x1 * (y2-y3)) / denom
    C     = (x2 * x3 * (x2-x3) * y1+x3 * x1 * (x3-x1) * y2+x1 * x2 * (x1-x2) * y3) / denom
    return A,B,C

beta_BPM27, beta_BPM28 = BPMx_Jbeta_Map[27:29]/Jconst_avg_weighted
A, B, C = calc_parabola_vertex(s_g7_bx, beta_BPM27, sstar_avg_weighted, Bstar_avg_weighted, s_g8_bx, beta_BPM28)
A_shift, B_shift, C_shift = calc_parabola_vertex(s_g7_bx - sstar_avg_weighted, beta_BPM27, 0, Bstar_avg_weighted, s_g8_bx - sstar_avg_weighted, beta_BPM28)
display(Math(r"\beta(s) = %fs^2 + %ds + %f"%(A_shift, B_shift, C_shift)))

s_space = np.linspace(s_g7_bx, s_g8_bx, 500)
Betatron = A*s_space**2 + B*s_space + C
s_points = [s_g7_bx, sstar_avg_weighted, s_g8_bx]
b_points = [beta_BPM27, Bstar_avg_weighted, beta_BPM28]

for x, y, text in zip(s_points, b_points, 
                      [Name_xbpms[27], r"$\beta^*$", Name_xbpms[28]]):
    plt.annotate(text, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
err_ypoints = np.zeros(3)
err_xpoints = np.zeros(3)

## Error Propagation on beta(s) = A/J
## s_b = sqrt((s_A*(1/J))^2 + (s_J*(-A/J^2))^2)
err_ypoints_beta = np.sqrt((BPMx_Jbeta_Map_err[27:29]*(1/Jconst_avg_weighted))**2 + (Jconst_stddev_weighted*BPMx_Jbeta_Map[27:29]/Jconst_avg_weighted**2)**2)
def error_prop_bsstar(b27, b28, b27_err, b28_err):
    a27 = b27/L27_28 + np.sqrt(b27*b28/L27_28**2 - 1)
    da27db27 = 1/L27_28 + b28/(2*L27_28**2*np.sqrt((b28*b27)/L27_28**2 - 1))
    da27db28 = b27/(2*L27_28**2*np.sqrt((b28*b27)/L27_28**2 - 1))
    
    s_star = s_g7_bx + a27*b27/(a27**2 + 1)
    ds_stardb27 = (-da27db27*a27**2*b27 + da27db27*b27 + a27**3 + a27)/(a27**2 + 1)**2
    ds_stardb28 = -da27db28*b27*(a27**2 - 1)/(a27**2 + 1)**2
#     print(s_star, sstar_avg_weighted)
    
    beta_star = b27/(a27**2 + 1)
    db_stardb27 = (-2*da27db27*a27*b27 + a27**2 + 1)/(a27**2 + 1)**2
    db_stardb28 = -2*da27db28*a27*b27/(a27**2 + 1)**2
#     print(beta_star, Bstar_avg_weighted)
    
    s_star_err_prop = np.sqrt((b27_err*ds_stardb27)**2 + (b28_err*ds_stardb28)**2)
    b_star_err_prop = np.sqrt((b27_err*db_stardb27)**2 + (b28_err*db_stardb28)**2)
    return s_star_err_prop, b_star_err_prop

print("Estimated values of Beta function at g7-bx & g8-bx:")
display(Math(r"\beta_{g7-bx} = %f; \beta_{g8-bx} = %f"%(beta_BPM27, beta_BPM28)))
print("Propagated error of Beta function at g7-bx & g8-bx based on varying J:")
s_star_err_prop, b_star_err_prop = error_prop_bsstar(beta_BPM27, beta_BPM28, *err_ypoints_beta)
display(Math(r"\sigma_{\beta_{g7-bx}} = %f; \sigma_{\beta_{g8-bx}} = %f"%(err_ypoints_beta[0], err_ypoints_beta[1])))

print("Estimated values of star values:")
display(Math(r"\Delta s^* = %f; \beta^* = %f"%(sstar_avg_weighted - sIP8, Bstar_avg_weighted)))
print("Propagated error of star values based on varying Beta function at g7-bx & g8-bx: ")
display(Math(r"\sigma_{s^*} = %f; \sigma_{\beta^*} = %f"%(s_star_err_prop, b_star_err_prop)))
err_ypoints[0] = err_ypoints_beta[0]
err_ypoints[1] = b_star_err_prop #Bstar_stddev_weighted
err_ypoints[2] = err_ypoints_beta[1]
err_xpoints[1] = s_star_err_prop #sstar_stddev_weighted

plt.errorbar(s_points, b_points, xerr = err_xpoints, yerr = err_ypoints, fmt = 'x', ecolor = 'r', capsize = 2)
plt.plot(s_space, Betatron)
plt.title("Betatron function of Weighted Average Results")
plt.xlabel("s")
plt.ylabel(r"$\beta$(s)")
#plt.set_xlim([639, 640])
#plt.set_ylim([0, 1])
plt.show()
# Out:
# $\displaystyle \beta(s) = 2.037952s^2 + 0s + 0.491127$
# Estimated values of Beta function at g7-bx & g8-bx:
# $\displaystyle \beta_{g7-bx} = 139.692487; \beta_{g8-bx} = 143.878209$
# Propagated error of Beta function at g7-bx & g8-bx based on varying J:
# $\displaystyle \sigma_{\beta_{g7-bx}} = 34.314788; \sigma_{\beta_{g8-bx}} = 34.697062$
# Estimated values of star values:
# $\displaystyle \Delta s^* = -0.062088; \beta^* = 0.491127$
# Propagated error of star values based on varying Beta function at g7-bx & g8-bx:
# $\displaystyle \sigma_{s^*} = 0.719004; \sigma_{\beta^*} = 0.085035$

# %% [markdown]
# ## Comparing Guillaume's values with my values

# %%
b1_g = 11.7**2

ss_g = .19918869 + sIP8
bs_g = .55506391

b2_g = 11.42**2

A_g, B_g, C_g = calc_parabola_vertex(s_g7_bx, b1_g, ss_g, bs_g, s_g8_bx, b2_g)
A_shift_g, B_shift_g, C_shift_g = calc_parabola_vertex(s_g7_bx - ss_g, b1_g, 0, bs_g, s_g8_bx - ss_g, b2_g)
print("After shift:")
display(Math(r"Guillaume: %fx^2 + %dx + %f"%(A_shift_g, B_shift_g, C_shift_g)))
display(Math(r"Will: %fx^2 + %dx + %f"%(A_shift, B_shift, C_shift)))

s_points_g = [s_g7_bx, ss_g, s_g8_bx]
b_points_g = [b1_g, bs_g, b2_g]
plt.plot(s_points_g, b_points_g, 'o', label = "Guillaume points")
for x, y, text in zip(s_points_g, b_points_g, [Name_xbpms[27], r"$\beta^*$", Name_xbpms[28]]):

    plt.annotate(text, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

for x, y, text in zip(s_points, b_points, [Name_xbpms[27], r"$\beta^*$", Name_xbpms[28]]):

    plt.annotate(text, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

Betatron_g = A_g*s_space**2 + B_g*s_space + C_g
plt.plot(s_space, Betatron_g, label = "Guillaume betatron function")
plt.plot(s_space, Betatron, label = "Will betatron function")
plt.errorbar(s_points, b_points, xerr = err_xpoints, yerr = err_ypoints, fmt = 'o', ecolor = 'r', capsize = 2, label = "Will error")
plt.title("Betatron function using BPMs")
plt.xlabel("s")
plt.ylabel(r"$\beta$(s)")
# plt.xlim([639, 640])
# plt.ylim([0, 1])
plt.legend()
plt.show()
# Out:
# After shift:
# $\displaystyle Guillaume: 1.919823x^2 + 0x + 0.555064$
# $\displaystyle Will: 2.037952x^2 + 0x + 0.491127$
